# %% [markdown]
# <a href="https://colab.research.google.com/github/SaifHu98/Qwanto/blob/main/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# تركيب Qwanto (إذا لم يكن مثبتًا)
# !pip install git+https://github.com/SaifHu98/Qwanto.git

# تحميل وتشغيل نموذج صغير
# from qwanto import Qwanto
# model = Qwanto.from_pretrained("path/to/model")
